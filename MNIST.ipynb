# %% [markdown]
# #Basic Neural Network-MNIST Dataset

# %%
import tensorflow as tf
import matplotlib.pyplot as plt

# %% [markdown]
# ## Loading the Dataset

# %%
mnist=tf.keras.datasets.mnist

# %%
(x_train,y_train),(x_test,y_test)=mnist.load_data()
# Out:
# ...
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step

# %% [markdown]
# ## Normalizing the images to a 0-1 range

# %%
x_train, x_test = x_train / 255.0, x_test / 255.0

# %%
plt.imshow(x_train[0], cmap='gray')
plt.title(f"Label: {y_train[0]}")
plt.show()

# %% [markdown]
# ## Defining Model

# %%
model=tf.keras.models.Sequential([
    tf.keras.layers.Flatten(input_shape=(28,28)),
    tf.keras.layers.Dense(128,activation='relu'),
    tf.keras.layers.Dropout(0,2),
    tf.keras.layers.Dense(10,activation='softmax')
])
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %% [markdown]
# ## Model Compilation

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# ## Training and Evaluation of the model

# %%
model.fit(x_train, y_train, epochs=5)

test_loss, test_acc = model.evaluate(x_test, y_test)
print(f"\nTest accuracy: {test_acc}")
# Out:
# Epoch 1/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9893 - loss: 0.0346
# Epoch 2/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.9920 - loss: 0.0268
# Epoch 3/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.9947 - loss: 0.0191
# Epoch 4/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9955 - loss: 0.0156
# Epoch 5/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.9956 - loss: 0.0151
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9753 - loss: 0.1004
#
# Test accuracy: 0.9793000221252441

# %% [markdown]
# ## Testing the Model

# %%
predictions = model.predict(x_test)

import numpy as np
plt.imshow(x_test[6], cmap='gray')
plt.title(f"Model Prediction: {np.argmax(predictions[6])}")
plt.show()
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %%
predictions = model.predict(x_test)

import numpy as np
plt.imshow(x_test[7], cmap='gray')
plt.title(f"Model Prediction: {np.argmax(predictions[7])}")
plt.show()
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step

# %%
predictions = model.predict(x_test)

import numpy as np
plt.imshow(x_test[18], cmap='gray')
plt.title(f"Model Prediction: {np.argmax(predictions[18])}")
plt.show()
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
